# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/Othercomputers/"Vivian's MacBook Pro 2021"/DS5899/attattr
# Out:
# [Errno 2] No such file or directory: "gdrive/Othercomputers/Vivian's MacBook Pro 2021/DS5899/attattr"
# /content/gdrive/Othercomputers/Vivian's MacBook Pro 2021/DS5899/attattr

# %%
# !pip install networkx
# !pip install --user matplotlib==3.1.0
# !pip install --user tensorboardX six numpy tqdm scikit-learn

# %%
# !python examples/attribution_tree.py --attr_file model_and_data/mnli_example/attr_zero_base_exp16.json --tokens_file model_and_data/mnli_example/tokens_and_pred_100.json --task_name mnli --example_index 16
# Out:
# examples/attribution_tree.py:41: RuntimeWarning: divide by zero encountered in true_divide
#   proportion_all[i] /= abs(proportion_all[i][1:,:].max())
# examples/attribution_tree.py:41: RuntimeWarning: invalid value encountered in true_divide
#   proportion_all[i] /= abs(proportion_all[i][1:,:].max())
# examples/attribution_tree.py:45: RuntimeWarning: invalid value encountered in multiply
#   proportion_all *= (proportion_all > threshold).astype(int)
# <Figure size 3000x2200 with 1 Axes>
